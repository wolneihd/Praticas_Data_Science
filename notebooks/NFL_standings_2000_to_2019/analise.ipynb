# %%
import pandas as pd
import matplotlib as plt

# %%
attendance = pd.read_csv('attendance.csv')
games = pd.read_csv('games.csv')
standings = pd.read_csv('standings.csv')

# %%
arizona = attendance['team'] == 'Arizona'
year = attendance['year'] == 2000
attendance[arizona & year].fillna(0)
# Out:
#        team  team_name  year   total    home    away  week  weekly_attendance
# 0   Arizona  Cardinals  2000  893926  387475  506451     1            77434.0
# 1   Arizona  Cardinals  2000  893926  387475  506451     2            66009.0
# 2   Arizona  Cardinals  2000  893926  387475  506451     3                0.0
# 3   Arizona  Cardinals  2000  893926  387475  506451     4            71801.0
# 4   Arizona  Cardinals  2000  893926  387475  506451     5            66985.0
# 5   Arizona  Cardinals  2000  893926  387475  506451     6            44296.0
# 6   Arizona  Cardinals  2000  893926  387475  506451     7            38293.0
# 7   Arizona  Cardinals  2000  893926  387475  506451     8            62981.0
# 8   Arizona  Cardinals  2000  893926  387475  506451     9            35286.0
# 9   Arizona  Cardinals  2000  893926  387475  506451    10            52244.0
# 10  Arizona  Cardinals  2000  893926  387475  506451    11            64223.0
# ...

# %%
home_team_arizona = games['home_team'] == 'Arizona Cardinals'
year_2000 = games['year'] == 2000
arizona_home_2000 = games[year_2000 & home_team_arizona]
home_win = arizona_home_2000['winner'] == 'Arizona Cardinals'
arizona_home_2000[home_win].set_index(keys='week')
# Out:
#       year          home_team            away_team             winner  tie  \
# week
# 2     2000  Arizona Cardinals       Dallas Cowboys  Arizona Cardinals  NaN
# 6     2000  Arizona Cardinals     Cleveland Browns  Arizona Cardinals  NaN
# 10    2000  Arizona Cardinals  Washington Redskins  Arizona Cardinals  NaN
#
#       day          date    time  pts_win  pts_loss  yds_win  turnovers_win  \
# week
# 2     Sun  September 10  8:35PM       32        31      322              1
# 6     Sun     October 8  4:15PM       29        21      315              2
# 10    Sun    November 5  4:05PM       16        15      178              2
#
#       yds_loss  turnovers_loss home_team_name home_team_city away_team_name  \
# week
# 2          330               2      Cardinals        Arizona        Cowboys
# 6          240               0      Cardinals        Arizona         Browns
# 10         422               3      Cardinals        Arizona       Redskins
#
#      away_team_city
# week
# ...

# %%
standings[standings['team'] == 'Miami']
# Out:
#       team team_name  year  wins  loss  points_for  points_against  \
# 0    Miami  Dolphins  2000    11     5         323             226
# 32   Miami  Dolphins  2001    11     5         344             290
# 64   Miami  Dolphins  2002     9     7         378             301
# 95   Miami  Dolphins  2003    10     6         311             261
# 129  Miami  Dolphins  2004     4    12         275             354
# 159  Miami  Dolphins  2005     9     7         318             317
# 193  Miami  Dolphins  2006     6    10         260             283
# 225  Miami  Dolphins  2007     1    15         267             437
# 254  Miami  Dolphins  2008    11     5         345             317
# 288  Miami  Dolphins  2009     7     9         360             390
# 320  Miami  Dolphins  2010     7     9         273             333
# 352  Miami  Dolphins  2011     6    10         329             313
# 383  Miami  Dolphins  2012     7     9         288             317
# ...
